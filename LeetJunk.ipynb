# %%
list1 = [1, 2, 4, 5, 6]
list2 = [0, 2, 3, 4, 5]
list3 = []
# Assuming two int lists are pre sorted, of vary length - find the intersections
len(list1)
len(list1)

for num in list1:
	for num1 in list2:
		if num == num1:
			list3.append(num)

print(list3)
list1 = [1, 2, 4, 5, 6]
list2 = [0, 2, 3, 4, 5]


list1.concat(list2)


def factorial(n):
	"""

    :param n:
    """
	n = 0

	def test():
		global n
		if n <= 0:
			n = 1
		else:
			n = n + 1

	test()


factorial(8)

print(n)


class Solution:
	def runningSum(self, nums: List[int]) -> List[int]:


import numpy as np


class Solution():

	def __init__(self, nums):
		self.nums = nums

	def runningSum(self):
		"""
        :type nums: List[int]
        :rtype: List[int]
        """
		return np.cumsum(self.nums)


nums = [1, 2, 3, 4]
Solve = Solution(nums)
Solve.runningSum()


class Solution():
	def __init__(self, nums):
		self.nums = nums

	def runningSum(self):
		results = np.cumsum(self.nums)
		return results


nums = [1, 2, 3, 4]
Solve = Solution(nums)

Solve.runningSum()


class Solution:
	def twoSum(self, num)
		for numI in num:
			print(numI)


Solution([2, 7, 11, 15])


class Solution():
	def twoSum(self, num, target):
		for num1 in num:
			for num2 in num:
				tempArray = []
				trySolve = num1 + num2
				if trySolve == target:
					tempArray.append(num.index(num1))
					tempArray.append(num.index(num2))
					return tempArray


nums = [2, 7, 11, 15]
Solution().twoSum(nums, 9)


class Solution():
	def twoSum(self, num, target):
		for idx1, num1 in enumerate(num):
			for idx2, num2 in enumerate(num):
				tempArray = []
				trySolve = num1 + num2
				if trySolve == target:
					if idx1 != idx2:
						tempArray.append(idx1)
						tempArray.append(idx2)
						return tempArray


nums = [3, 2, 4]
Solution.twoSum(nums, 6)


def twoSum(num, target):
	arrLength = Length


class Solution:
	def twoSum(self, nums: List[int], target: int) -> List[int]:
		for index, val in enumerate(nums):
			for i in range(index + 1, len(nums)):
				if val + nums[i] == target:
					return [index, i]


class Base:
	def __init__(self, path, name):
		self.path_file = path
		self.file_name = name

	def showPath(self):
		print(self.path_file)
	# with h5py.File(path+name+'.h5','r') as hdf:
	#
	#     G  = hdf.get('Physical Parameters')
	#     self.kvector     = G.attrs.get('k vector')
	#     self.gamma       = G.attrs.get('Decay rate of transition (Hz)')
	#     self.L00         = G.attrs.get('Wavelength of main cycling transition (nm)')
	#     self.linewidth   = G.attrs.get('Linewidth of transition (MHz)')
	#     self.m_amu       = G.attrs.get('Atomic mass')
	#     self.m_kg        = G.attrs.get('Mass in kg')
	#
	#     # get all the natural units used to solve the problem
	#     G1 = hdf.get('Natural units')
	#     self.t0          = G1.attrs.get('Natural time scale (lifetime)')
	#     self.x0          = G1.attrs.get('Natural length scale')
	#     self.v0          = G1.attrs.get('Doppler velocity (m/s)')
	#     self.mbar        = G1.attrs.get('Dimensionless mass')


class OtherClass(Base):
	def __init__(self, name, path, othervalue):
		super().__init__(path, name)
		self.othervalue = othervalue


Thing = OtherClass('Its a path!', 'its a name', 'and heres something the parent class didnt have')
Thing.showPath()


class Solution:
	def twoSum(self, nums, target):
		indices = []
		for ii in range(len(nums)):
			for jj in range(len(nums)):
				check = nums[ii] + nums[jj]
				if check == target:
					indices.append(jj)
		return indices


ret = Solution().twoSum(nums, target)


class Solution:
	def twoSum(self, nums, target):
		indices = []
		for ii in range(len(nums)):
			for jj in range(len(nums)):
				check = nums[ii] + nums[jj]
				if check == target:
					if ii != jj:
						return [jj, ii]


Solution().twoSum(nums, target)


class Solution:
	def twoSum(self, nums, target):
		for idx in range(len(nums)):
			remainder = target - nums[idx]
			ridx = nums.index(remainder) if remainder in nums else idx
			if idx != ridx:
				return [idx, ridx]


alist = [3, 3]
t = 6

Solution.twoSum(Solution, nums=alist, target=t)


class Solution:
	def twoSum(self, nums, target):
		for idx, num in enumerate(nums):
			remainder = target - nums[idx]
			ridx = nums.index(remainder) if remainder in nums else idx
			if idx != ridx:
				return [idx, ridx]


alist = [3, 3]
t = 6

Solution.twoSum(Solution, nums=alist, target=t)


class Solution:
	def twoSum(self, nums: list, target: int):
		for idx in range(len(nums)):
			remainder: int = target - nums[idx]
			try:
				ridx: int = nums.index(remainder, idx + 1)
			except ValueError:
				continue
			return [idx, ridx]


alist = [3, 3]
t = 6

Solution.twoSum(Solution, nums=alist, target=t)


class Solution:
	def twoSum(self, nums: list, target: int):
		hashtable = {num: idx for idx, num in enumerate(nums)}
		print(hashtable)
		for idx in range(len(nums)):
			remainder: int = (target - nums[idx])
			hashIndex: int = hashtable[remainder] if remainder in hashtable else idx
			if remainder in hashtable and hashIndex != idx:
				return [idx, hashIndex]



class Solution:
	def twoSum(self, nums: list, target: int):
		hashtable = {num: idx for idx, num in enumerate(nums)}
		print(hashtable)
		for idx in range(len(nums)):
			remainder: int = (target - nums[idx])
			hashIndex: int = hashtable[remainder] if remainder in hashtable else idx
			if remainder in hashtable and hashIndex != idx:
				return [idx, hashIndex]

	# idx, val = "idx", "vals"
	# res = {idx : [], val : []}
	# for id, vl in enumerate(nums):
	#     res[idx].append(id)
	#     res[val].append(vl)
	#     remainder : int = target - res.get[id]
	#     print(remainder)
	# r = res.get(remainder)
	#
	# print(r)

	# for idx in range(len(nums)):
	#     remainder : int = target - nums[idx]
	#     try:
	#         ridx : int = nums.index(remainder, idx+1)
	#     except ValueError:
	#         continue
	#     return [idx, ridx]


alist = [3, 3]
t = 6
Solution.twoSum(Solution, nums=alist, target=t)


class Solution:
	def twoSum(self, nums: list, target: int):
		for idx in range(len(nums)):
			remainder: int = target - nums[idx]
			try:
				ridx: int = nums.index(remainder, idx + 1)
			except ValueError:
				continue
			return [idx, ridx]


class Solution:
	def twoSum(self, nums, target):
		arrLength1 = len(nums)
		for idx in range(arrLength1):
			remainder = target - nums[idx]
			ridx = nums.index(remainder) if remainder in nums else idx
			if (idx != ridx) & ((nums[idx] + nums[ridx]) == target):
				return [idx, ridx]

# %%
from collections import deque

deque(['a','b','c'])

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: Optional[ListNode], l2: Optional[ListNode]) -> Optional[ListNode]:







[2,4,3]
[5,6,4]
[0]
[0]
[9,9,9,9,9,9,9]
[9,9,9,9]

# %%
def romanToInt(self, s: str):
		sym_dict = {'I': 1,
					'V': 5,
					'X': 10,
					'L': 50,
					'C': 100,
					'D': 500,
					'M': 1000
					};
		str_list = [sym_dict.get(x) for x in s]
		print(str_list)
# Out:
#   Input In [1]
#     str_list = [x for sym_dict.get(x) in s]
#                       ^
# SyntaxError: cannot assign to function call
